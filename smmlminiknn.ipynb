# %%
import pandas as pd
from imblearn.over_sampling import SMOTE

file_path = '/content/drive/MyDrive/miniprojectfin.csv'
data = pd.read_csv(file_path)
data

# %%
data.isnull().sum()
# Out:
# Product_Id                     0
# Product_Weight                 0
# Product_Sugar_Content          0
# Product_Allocated_Area       188
# Product_Type                   0
# Product_MRP                    0
# Store_Id                       0
# Store_Establishment_Year       0
# Store_Size                     0
# Store_Location_City_Type       0
# Store_Type                     0
# Product_Store_Sales_Total      0
# dtype: int64

# %%
data['Product_Allocated_Area']=data['Product_Allocated_Area'].ffill()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Product_Id'] = le.fit_transform(data['Product_Id'])
data['Product_Sugar_Content'] = le.fit_transform(data['Product_Sugar_Content'])
data['Product_Type'] = le.fit_transform(data['Product_Type'])
data['Store_Id'] = le.fit_transform(data['Store_Id'])
data['Store_Size'] = le.fit_transform(data['Store_Size'])
data['Store_Location_City_Type'] = le.fit_transform(data['Store_Location_City_Type'])
data['Store_Type'] = le.fit_transform(data['Store_Type'])
data['Product_Store_Sales_Total'] = le.fit_transform(data['Product_Store_Sales_Total'])
X = data.drop('Product_Store_Sales_Total', axis=1)
y = data['Product_Store_Sales_Total']


smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)


df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='target')], axis=1)

df_resampled.to_csv('smresampled_dataset.csv', index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# %%
data1= pd.read_csv('/content/smresampled_dataset.csv')
data1
# Out:
#        Product_Id  Product_Weight  Product_Sugar_Content  \
# 0            4959       12.660000                      0
# 1            6380       16.540000                      0
# 2            4096       14.280000                      2
# 3            6701       12.100000                      0
# 4            7282        9.570000                      1
# ...           ...             ...                    ...
# 15637        7338        9.901069                      1
# 15638         635        8.951241                      0
# 15639        6181       13.090781                      0
# 15640        3630       11.427425                      0
# 15641        3628       13.609820                      2
#
#        Product_Allocated_Area  Product_Type  Product_MRP  Store_Id  \
# 0                    0.027000             5   117.080000         3
# 1                    0.144000             4   171.430000         2
# 2                    0.031000             3   162.080000         0
# 3                    0.112000             0   186.310000         0
# 4                    0.010000             8   123.670000         1
# ...                       ...           ...          ...       ...
# 15637                0.052863             8   139.553093         3
# 15638                0.044021            14    98.830594         1
# 15639                0.120837            14   108.762979         2
# 15640                0.067484             6   126.114765         3
# 15641                0.027490             6   151.006870         1
#
#        Store_Establishment_Year  Store_Size  Store_Location_City_Type  \
# 0                          2009           1                         1
# 1                          1999           1                         0
# 2                          1987           0                         1
# 3                          1987           0                         1
# 4                          1998           2                         2
# ...                         ...         ...                       ...
# 15637                      2009           1                         1
# 15638                      1998           2                         2
# 15639                      2008           1                         1
# 15640                      2009           1                         1
# 15641                      2001           1                         1
#
#        Store_Type  target
# 0               3       1
# 1               0       2
# 2               2       2
# 3               2       2
# 4               1       1
# ...           ...     ...
# 15637           3       1
# 15638           1       1
# 15639           2       1
# 15640           3       1
# 15641           1       1
#
# [15642 rows x 12 columns]

# %%
X = data1.iloc[:,0:11]
y = data1['target']



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

k = 5
knn = KNeighborsClassifier(n_neighbors=k)


knn.fit(X_train, y_train)


y_pred = knn.predict(X_test)
y_pred_proba = knn.predict_proba(X_test)[:, 1]


accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)


print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{classification_rep}")
# Out:
# Accuracy: 0.9434324065196549
# Confusion Matrix:
# [[ 990    2   32]
#  [   2 1024   49]
#  [  41   51  938]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      1024
#            1       0.95      0.95      0.95      1075
#            2       0.92      0.91      0.92      1030
#
#     accuracy                           0.94      3129
#    macro avg       0.94      0.94      0.94      3129
# weighted avg       0.94      0.94      0.94      3129

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,3))
sns.heatmap(conf_matrix,annot=True,cmap='Blues',cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
report=classification_report(y_test,y_pred)
print("Classification Report:\n", report)
