# %%
import pandas as pd



data = pd.read_csv('/content/drive/MyDrive/rosresampled_dataset.csv')
data.head(5)
# Out:
#   Product_Id  Product_Weight Product_Sugar_Content  Product_Allocated_Area  \
# 0     FD6114           12.66             Low Sugar                   0.027
# 1     FD7839           16.54             Low Sugar                   0.144
# 2     FD5075           14.28               Regular                   0.031
# 3     FD8233           12.10             Low Sugar                   0.112
# 4     NC1180            9.57              No Sugar                   0.010
#
#          Product_Type  Product_MRP Store_Id  Store_Establishment_Year  \
# 0        Frozen Foods       117.08   OUT004                      2009
# 1               Dairy       171.43   OUT003                      1999
# 2              Canned       162.08   OUT001                      1987
# 3        Baking Goods       186.31   OUT001                      1987
# 4  Health and Hygiene       123.67   OUT002                      1998
#
#   Store_Size Store_Location_City_Type          Store_Type target
# 0     Medium                   Tier 2   Supermarket Type2      L
# 1     Medium                   Tier 1  Departmental Store      M
# 2       High                   Tier 2   Supermarket Type1      M
# 3       High                   Tier 2   Supermarket Type1      M
# 4      Small                   Tier 3           Food Mart      L

# %%
data.isnull().sum()
# Out:
# Product_Id                    0
# Product_Weight                0
# Product_Sugar_Content         0
# Product_Allocated_Area      349
# Product_Type                  0
# Product_MRP                   0
# Store_Id                      0
# Store_Establishment_Year      0
# Store_Size                    0
# Store_Location_City_Type      0
# Store_Type                    0
# target                        0
# dtype: int64

# %%
data['Product_Allocated_Area']=data['Product_Allocated_Area'].ffill()

# %%
data.isnull().sum()
# Out:
# Product_Id                  0
# Product_Weight              0
# Product_Sugar_Content       0
# Product_Allocated_Area      0
# Product_Type                0
# Product_MRP                 0
# Store_Id                    0
# Store_Establishment_Year    0
# Store_Size                  0
# Store_Location_City_Type    0
# Store_Type                  0
# target                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Product_Id'] = le.fit_transform(data['Product_Id'])
data['Product_Sugar_Content'] = le.fit_transform(data['Product_Sugar_Content'])
data['Product_Type'] = le.fit_transform(data['Product_Type'])
data['Store_Id'] = le.fit_transform(data['Store_Id'])
data['Store_Size'] = le.fit_transform(data['Store_Size'])
data['Store_Location_City_Type'] = le.fit_transform(data['Store_Location_City_Type'])
data['Store_Type'] = le.fit_transform(data['Store_Type'])
data['target'] = le.fit_transform(data['target'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


X = data.iloc[:,0:11]
y = data['target']  # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=35)

# Standardize features (recommended for SVM)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initialize the SVM classifier
clf = SVC(kernel='rbf', random_state=42)  # 'rbf' kernel is commonly used

# Fit the classifier to the training data
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{classification_rep}")
# Out:
# Accuracy: 0.9379993608181527
# Confusion Matrix:
# [[1006   12   41]
#  [   0  993   21]
#  [  81   39  936]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1059
#            1       0.95      0.98      0.97      1014
#            2       0.94      0.89      0.91      1056
#
#     accuracy                           0.94      3129
#    macro avg       0.94      0.94      0.94      3129
# weighted avg       0.94      0.94      0.94      3129

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,3))
sns.heatmap(conf_matrix,annot=True,cmap='Blues',cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
report=classification_report(y_test,y_pred)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1059
#            1       0.95      0.98      0.97      1014
#            2       0.94      0.89      0.91      1056
#
#     accuracy                           0.94      3129
#    macro avg       0.94      0.94      0.94      3129
# weighted avg       0.94      0.94      0.94      3129
